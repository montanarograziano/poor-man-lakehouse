# %%
from poor_man_lakehouse.polars_connector import PolarsClient, load_sql_magic

client = PolarsClient()
load_sql_magic(client)
# Out:
# ✓ SQL magic loaded. Use %%sql to query Unity Catalog tables.
#   Example:
#     %%sql
#     SELECT * FROM unity.default.test_table

# %%
print(client.show_catalog_tree())
# Out:
# 📁 unity
#   📂 default
#       ├── 📄 marksheet
#       ├── 📄 marksheet_uniform
#       ├── 📄 numbers
#       ├── 📄 test_table
#       └── 📄 user_countries
#   📂 demo

# %%
# %%sqlp
# select * from unity.default.test_table
# Out:
# <div style='color: #666; font-size: 12px; margin-bottom: 8px;'><b>3 rows</b> in <b>0.08s</b></div>
# shape: (3, 2)
# ┌─────────┬───────┐
# │ country ┆ value │
# │ ---     ┆ ---   │
# │ str     ┆ i64   │
# ╞═════════╪═══════╡
# │ US      ┆ 100   │
# │ CA      ┆ 200   │
# │ MX      ┆ 300   │
# └─────────┴───────┘
# shape: (3, 2)
# ┌─────────┬───────┐
# │ country ┆ value │
# │ ---     ┆ ---   │
# │ str     ┆ i64   │
# ╞═════════╪═══════╡
# │ US      ┆ 100   │
# │ CA      ┆ 200   │
# │ MX      ┆ 300   │
# └─────────┴───────┘
